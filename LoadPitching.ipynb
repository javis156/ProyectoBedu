# %%
import pandas as pd

# %%
df_salaries = pd.read_csv('archive-3/Pitching.csv')

# %%
df_salaries
# Out:
#         playerID  yearID  stint teamID lgID   W   L   G  GS  CG  ...  IBB  \
# 0      bechtge01    1871      1    PH1  NaN   1   2   3   3   2  ...  NaN
# 1      brainas01    1871      1    WS3  NaN  12  15  30  30  30  ...  NaN
# 2      fergubo01    1871      1    NY2  NaN   0   0   1   0   0  ...  NaN
# 3      fishech01    1871      1    RC1  NaN   4  16  24  24  22  ...  NaN
# 4      fleetfr01    1871      1    NY2  NaN   0   1   1   1   1  ...  NaN
# ...          ...     ...    ...    ...  ...  ..  ..  ..  ..  ..  ...  ...
# 44134  youngch03    2015      1    KCA   AL  11   6  34  18   0  ...  0.0
# 44135  zieglbr01    2015      1    ARI   NL   0   3  66   0   0  ...  3.0
# 44136  zimmejo02    2015      1    WAS   NL  13  10  33  33   0  ...  3.0
# 44137   zitoba01    2015      1    OAK   AL   0   0   3   2   0  ...  0.0
# 44138   zychto01    2015      1    SEA   AL   0   0  13   1   0  ...  0.0
#
#         WP  HBP  BK    BFP    GF    R   SH   SF  GIDP
# ...

# %%
import sqlalchemy as sal
from sqlalchemy import create_engine

# %%
pip install pymysql
# Out:
# ...
#      |████████████████████████████████| 43 kB 160 kB/s eta 0:00:011
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
server = ''
db = ''
engine = create_engine('mysql+pymysql://encanto4_User:ProyectoBedu@162.241.203.101/encanto4_ProyectoBedu?charset=utf8mb4', echo=False)
conn = engine.connect()

# %%
df_salaries.to_sql("Pitching",conn,if_exists = 'append',index = False)

# %%
conn.close()

# %%
pd.read_sql('SELECT * FROM encanto4_ProyectoBedu.Pitching',conn)
# Out:
#         playerID  yearID  stint teamID lgID   W   L   G  GS  CG  ...  IBB  WP  \
# 0      bechtge01    1871      1    PH1   NA   1   2   3   3   2  ...
# 1      brainas01    1871      1    WS3   NA  12  15  30  30  30  ...
# 2      fergubo01    1871      1    NY2   NA   0   0   1   0   0  ...
# 3      fishech01    1871      1    RC1   NA   4  16  24  24  22  ...
# 4      fleetfr01    1871      1    NY2   NA   0   1   1   1   1  ...
# ...          ...     ...    ...    ...  ...  ..  ..  ..  ..  ..  ...  ...  ..
# 44220  youngch03    2015      1    KCA   AL  11   6  34  18   0  ...    0   5
# 44221  zieglbr01    2015      1    ARI   NL   0   3  66   0   0  ...    3   2
# 44222  zimmejo02    2015      1    WAS   NL  13  10  33  33   0  ...    3   2
# 44223   zitoba01    2015      1    OAK   AL   0   0   3   2   0  ...    0   0
# 44224   zychto01    2015      1    SEA   AL   0   0  13   1   0  ...    0   1
#
#        HBP  BK  BFP  GF    R  SH SF  GIDP
# 0            0            42
# ...
